# %%
import pandas as pd

# %%
data = pd.read_excel("reporte de descripciones.xls")
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'

# %%
data
# Out:
#                 Unnamed: 0  Unnamed: 1                     Unnamed: 2  \
# 0                      NaN         NaN                            NaN
# 1                      NaN         NaN                            NaN
# 2                      NaN         NaN                            NaN
# 3                      NaN         NaN                            NaN
# 4                    Clave         NaN                    Descripcion
# 5                      NaN         NaN                            NaN
# 6                      100         NaN               GERENCIA GENERAL
# 7                      101         NaN               RECURSOS HUMANOS
# 8                    101-A         NaN                         COCINA
# 9                      102         NaN             MATERIALES/COMPRAS
# 10                   102-A         NaN             MATERIALES/RECIBOS
# 11                     103         NaN             CONTROL DE CALIDAD
# ...

# %%
result = data.loc[6:40], ['Unnamed: 0', "Unnamed: 2"]

# %%
result
# Out:
# (   Unnamed: 0  Unnamed: 1                     Unnamed: 2  Unnamed: 3  \
#  6         100         NaN               GERENCIA GENERAL         NaN
#  7         101         NaN               RECURSOS HUMANOS         NaN
#  8       101-A         NaN                         COCINA         NaN
#  9         102         NaN             MATERIALES/COMPRAS         NaN
#  10      102-A         NaN             MATERIALES/RECIBOS         NaN
#  11        103         NaN             CONTROL DE CALIDAD         NaN
#  12       103M         NaN      CONTROL DE CALIDAD MOLDEO         NaN
#  13       103P         NaN     CONTROL DE CALIDAD PINTURA         NaN
#  14      103-S         NaN                   SWAT-QA-TEAM         NaN
#  15        104         NaN                       FINANZAS         NaN
#  16        105         NaN                     PRODUCCION         NaN
#  17      105-A         NaN          PRODUCCION/SUPERVISOR         NaN
# ...
